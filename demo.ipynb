# %% [markdown]
# # Object Detection with SSD
# ### Here we demostrate detection on example images using SSD with PyTorch

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
from torch.autograd import Variable
import numpy as np
import cv2
if torch.cuda.is_available():
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

from ssd import build_ssd

# %% [markdown]
# ## Build SSD300 in Test Phase
# 1. Build the architecture, specifyingsize of the input image (300),
#     and number of object classes to score (21 for VOC dataset)
# 2. Next we load pretrained weights on the VOC0712 trainval dataset

# %%
net = build_ssd('test', 300, 21)    # initialize SSD
net.load_weights('../weights/ssd300_mAP_77.43_v2.pth')
# Out:
# Loading weights into state dict...
# Finished!
# C:\Users\jjang\Documents\github\ssd.pytorch\ssd.py:34: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   self.priors = Variable(self.priorbox.forward(), volatile=True)
# C:\Users\jjang\Documents\github\ssd.pytorch\layers\modules\l2norm.py:17: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   init.constant(self.weight,self.gamma)

# %%
net.load_weights('../weights/ssd300_mAP_77.43_v2.pth')
# Out:
# Loading weights into state dict...
# Finished!

# %% [markdown]
# ## Load Image
# ### Here we just load a sample image from the VOC07 dataset

# %%
# image = cv2.imread('../data/example.jpg', cv2.IMREAD_COLOR)  # uncomment if dataset not downloaded
image = cv2.imread('../data/scripts/VOCdevkit/VOC2007/JPEGImages/000019.jpg', cv2.IMREAD_COLOR)  # uncomment if dataset not downloaded
# %matplotlib inline
from matplotlib import pyplot as plt
#from .data import VOCDetection, VOC_ROOT, VOCAnnotationTransform
# here we specify year (07 or 12) and dataset ('test', 'val', 'train') 
#testset = VOCDetection(VOC_ROOT, [('2007', 'val')], None, VOCAnnotationTransform())
#img_id = 60
#image = testset.pull_image(img_id)
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# View the sampled input image before transform
plt.figure(figsize=(10,10))
plt.imshow(rgb_image)
plt.show()

# %% [markdown]
# ## Pre-process the input.
# #### Using the torchvision package, we can create a Compose of multiple built-in transorm ops to apply
# For SSD, at test time we use a custom BaseTransform callable to
# resize our image to 300x300, subtract the dataset's mean rgb values,
# and swap the color channels for input to SSD300.

# %%
x = cv2.resize(image, (300, 300)).astype(np.float32)
x -= (104.0, 117.0, 123.0)
x = x.astype(np.float32)
x = x[:, :, ::-1].copy()
plt.imshow(x)
x = torch.from_numpy(x).permute(2, 0, 1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## SSD Forward Pass
# ### Now just wrap the image in a Variable so it is recognized by PyTorch autograd

# %%
xx = Variable(x.unsqueeze(0))     # wrap tensor in Variable
if torch.cuda.is_available():
    xx = xx.cuda()
y = net(xx)
# Out:
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(44)forward()
# -> for i in range(num):
# (Pdb) conf_preds.shape
# torch.Size([1, 21, 8732])
# (Pdb) n
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(45)forward()
# -> decoded_boxes = decode(loc_data[i], prior_data, self.variance)
# (Pdb) n
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(47)forward()
# -> conf_scores = conf_preds[i].clone()
# (Pdb) n
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(49)forward()
# -> for cl in range(1, self.num_classes):
# (Pdb) n
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(50)forward()
# -> c_mask = conf_scores[cl].gt(self.conf_thresh)
# (Pdb) n
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(51)forward()
# -> scores = conf_scores[cl][c_mask]
# (Pdb) n
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(52)forward()
# -> if scores.dim() == 0:
# (Pdb) scores
# tensor([])
# (Pdb) conf_scores
# tensor([[9.9451e-01, 9.9552e-01, 9.9524e-01,  ..., 9.9982e-01, 9.7565e-01,
#          9.9999e-01],
#         [2.5335e-04, 1.3176e-04, 2.8825e-04,  ..., 9.5691e-10, 2.7510e-08,
#          7.3582e-11],
#         [1.6296e-04, 1.1261e-04, 1.1214e-04,  ..., 7.4023e-11, 4.0808e-09,
#          7.1047e-12],
#         ...,
#         [2.5722e-04, 1.8377e-04, 2.0833e-04,  ..., 1.3758e-05, 2.5400e-04,
#          3.5556e-06],
#         [1.4625e-04, 1.5405e-04, 1.4305e-04,  ..., 1.7263e-08, 1.3374e-06,
#          5.1925e-10],
#         [2.3426e-04, 3.5722e-04, 1.6296e-04,  ..., 4.3344e-06, 2.7924e-04,
#          4.5570e-07]])
# (Pdb) conf_scores.shape
# torch.Size([21, 8732])
# (Pdb) conf_scores[cl].shape
# torch.Size([8732])
# (Pdb) conf_scores[cl].max()
# tensor(0.0020)
# (Pdb) c
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-78366ddad8a1> in <module>()
#       2 if torch.cuda.is_available():
#       3     xx = xx.cuda()
# ----> 4 y = net(xx)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~\Documents\github\ssd.pytorch\ssd.py in forward(self, x)
#     101                 self.softmax(conf.view(conf.size(0), -1,
#     102                              self.num_classes)),                # conf preds
# --> 103                 self.priors.type(type(x.data))                  # default boxes
#     104             )
#     105         else:
#
# ~\Documents\github\ssd.pytorch\layers\functions\detection.py in forward(self, loc_data, conf_data, prior_data)
#      50                 c_mask = conf_scores[cl].gt(self.conf_thresh)
#      51                 scores = conf_scores[cl][c_mask]
# ---> 52                 if scores.dim() == 0:
#      53                     continue
#      54                 l_mask = c_mask.unsqueeze(1).expand_as(decoded_boxes)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
net(xx)
# Out:
# > c:\users\jjang\documents\github\ssd.pytorch\layers\functions\detection.py(44)forward()
# -> for i in range(num):
# (Pdb) c
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ae3e4b98de34> in <module>()
# ----> 1 net(xx)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~\Documents\github\ssd.pytorch\ssd.py in forward(self, x)
#     101                 self.softmax(conf.view(conf.size(0), -1,
#     102                              self.num_classes)),                # conf preds
# --> 103                 self.priors.type(type(x.data))                  # default boxes
#     104             )
#     105         else:
#
# ~\Documents\github\ssd.pytorch\layers\functions\detection.py in forward(self, loc_data, conf_data, prior_data)
#      42
#      43         # Decode predictions into bboxes.
# ---> 44         for i in range(num):
#      45             decoded_boxes = decode(loc_data[i], prior_data, self.variance)
#      46             # For each class, perform nms
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %% [markdown]
# ## Parse the Detections and View Results
# Filter outputs with confidence scores lower than a threshold
# Here we choose 60%

# %%
from data import VOC_CLASSES as labels
top_k=10

plt.figure(figsize=(10,10))
colors = plt.cm.hsv(np.linspace(0, 1, 21)).tolist()
plt.imshow(rgb_image)  # plot the image for matplotlib
currentAxis = plt.gca()

detections = y.data
# scale each detection back up to the image
scale = torch.Tensor(rgb_image.shape[1::-1]).repeat(2)
for i in range(detections.size(1)):
    j = 0
    while detections[0,i,j,0] >= 0.6:
        score = detections[0,i,j,0]
        label_name = labels[i-1]
        display_txt = '%s: %.2f'%(label_name, score)
        pt = (detections[0,i,j,1:]*scale).cpu().numpy()
        coords = (pt[0], pt[1]), pt[2]-pt[0]+1, pt[3]-pt[1]+1
        color = colors[i]
        currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor=color, linewidth=2))
        currentAxis.text(pt[0], pt[1], display_txt, bbox={'facecolor':color, 'alpha':0.5})
        j+=1
